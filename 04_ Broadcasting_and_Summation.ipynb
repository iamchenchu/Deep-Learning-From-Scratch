# %% [markdown]
# ### Broadcasting and array summation in Python
#
# ![image.png](attachment:12ebaf0e-b816-44c1-86ec-61ca2da86f47.png)

# %%
import numpy as np

A = [[1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]]

print(np.sum(A)) #It adds all the elements in the array and give us the total sum of the elements
# Out:
# 45

# %%
axis_0_sum = np.sum(A, axis=0)

print(axis_0_sum)

print("The dimesion is :", axis_0_sum.ndim)
# Out:
# [12 15 18]
# The dimesion is : 1

# %%
axis_1_sum = np.sum(A, axis=1)

print(axis_1_sum)

print("The dimesion is :", axis_1_sum.ndim)
# Out:
# [ 6 15 24]
# The dimesion is : 1

# %%
axis_0_sum = np.sum(A, axis=0, keepdims=True)

print(axis_0_sum)

print("The dimesion is :", axis_0_sum.ndim)
# Out:
# [[12 15 18]]
# The dimesion is : 2

# %% [markdown]
# axis_1_sum = np.sum(A, axis=1, keepdims=True)
#
# print(axis_1_sum)
#
# print("The dimesion is :", axis_1_sum.ndim)

# %% [markdown]
# ## Broadcasting Rules
#
# ![image.png](attachment:d92cd79c-3487-4992-8a81-e1a98ee611d0.png)
