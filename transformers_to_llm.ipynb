# %% [markdown]
# Overview
#
# ![image.png](attachment:2835fc24-3ed2-4948-958e-2daeabb7ace3.png)

# %% [markdown]
# __What is Generative AI__ : All chatGPT and similar products are belong to these categories
#
# __Applications :__
# - Image Creation: https://copilot.microsoft.com/
#
# - Video Creation: https://app.runwayml.com/
#
# - PPT creation: https://gamma.app/
